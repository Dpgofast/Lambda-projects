# %% [markdown]
# <a href="https://colab.research.google.com/github/Dpgofast/Lambda-projects/blob/master/storytellingproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install xlrd
import pandas as pd 

sep18=pd.read_excel('exh2s.xls')
sep18.head
# Out:
# <bound method NDFrame.head of    Exhibit 2. Origin of Movement of U.S. Exports of Goods by State by NAICS-Based Product Code Groupings,  \
# 0                       Not Seasonally Adjusted: 2018
# 1                                                 NaN
# 2   In millions of dollars. Foreign Trade Zone (FT...
# 3   and territories. Separate FTZ total line is fo...
# 4   (-) Represents zero or less than one-half unit...
# 5                                                 NaN
# 6                                                Item
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                         U.S. Total
# 12                                 Foreign Trade Zone
# 13                                                NaN
# 14                                            Alabama
# ...
